# %% [markdown]
# # Vizualization of final dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Load Dataframe

# %%
df = pd.read_pickle('data/reg_model_data_final.pkl')

# %%
df.head()
# Out:
#    year       DATE         Home            Away  label_h_point_spread  \
# 0  2007 2007-01-01  Wake Forest   East Carolina                  16.0
# 1  2007 2007-01-01    Creighton    Illinois St.                   8.0
# 2  2007 2007-01-01   Texas Tech      New Mexico                   2.0
# 3  2007 2007-01-01  Chicago St.  New Mexico St.                 -10.0
# 4  2007 2007-01-01      Alabama        Oklahoma                  15.0
#
#    label_home_winner  month  home_bpg  home_drebpg  home_orebpg    ...      \
# 0                  1      1  3.750000    22.583333    11.333333    ...
# 1                  1      1  2.545455    21.181818    11.545455    ...
# 2                  1      1  1.928571    20.357143     7.714286    ...
# 3                  0      1  3.705882    17.764706    10.352941    ...
# 4                  1      1  6.846154    28.461538    12.307692    ...
#
#    pyth_wp_home  pyth_wp_away  hometeam_ps_var  awayteam_ps_var  home_tovpct  \
# 0      0.837209      0.882939       343.608187       145.888783     0.186440
# 1      0.975231      0.861308       244.286549       128.979898     0.154769
# 2      0.935429      0.670642       294.236948       359.185185     0.154327
# 3      0.902584      0.801251       324.575980       116.863142     0.180176
# 4      0.989624      0.757776       321.533198       116.428571     0.165873
#
#    away_tovpct  home_ft_factor  away_ft_factor  home_pace  away_pace
# 0     0.164656        0.315315        0.209776  59.666667  57.444444
# 1     0.208097        0.296796        0.186846  54.000000  62.333333
# 2     0.162184        0.278772        0.298789  60.142857  60.923077
# 3     0.201647        0.244898        0.373333  61.823529  60.090909
# 4     0.205315        0.249347        0.201452  60.230769  60.600000
#
# [5 rows x 65 columns]

# %% [markdown]
# ### Create features dataframe

# %%
df_features = df.copy()

# %%
df_features.drop(['year','DATE','Home','Away','month','label_h_point_spread','label_home_winner'],axis=1, inplace=True)

# %%
df_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37498 entries, 0 to 37497
# Data columns (total 58 columns):
# home_bpg            37498 non-null float64
# home_drebpg         37498 non-null float64
# home_orebpg         37498 non-null float64
# home_trebpg         37498 non-null float64
# home_foulpg         37498 non-null float64
# home_ppg            37498 non-null float64
# home_stlpg          37498 non-null float64
# home_topg           37498 non-null float64
# home_3papg          37498 non-null float64
# home_fgapg          37498 non-null float64
# home_ftapg          37498 non-null float64
# home_apg            37498 non-null float64
# home_fgp_var        37498 non-null float64
# home_ppg_var        37498 non-null float64
# away_bpg            37498 non-null float64
# away_drebpg         37498 non-null float64
# away_orebpg         37498 non-null float64
# away_trebpg         37498 non-null float64
# away_foulpg         37498 non-null float64
# away_ppg            37498 non-null float64
# away_stlpg          37498 non-null float64
# away_topg           37498 non-null float64
# away_3papg          37498 non-null float64
# away_fgapg          37498 non-null float64
# away_ftapg          37498 non-null float64
# away_apg            37498 non-null float64
# away_fgp_var        37498 non-null float64
# away_ppg_var        37498 non-null float64
# home_ps_home        37498 non-null float64
# away_ps_away        37498 non-null float64
# home_fgpct          37498 non-null float64
# away_fgpct          37498 non-null float64
# home_3ppct          37498 non-null float64
# away_3ppct          37498 non-null float64
# home_ftpct          37498 non-null float64
# away_ftpct          37498 non-null float64
# home_efgpct         37498 non-null float64
# away_efgpct         37498 non-null float64
# hometeam_games      37498 non-null float64
# hometeam_wp         37498 non-null float64
# hometeam_homewp     37498 non-null float64
# awayteam_games      37498 non-null float64
# awayteam_wp         37498 non-null float64
# awayteam_awaywp     37498 non-null float64
# hometeam_pt_sprd    37498 non-null float64
# hometeam_opp_ppg    37498 non-null float64
# awayteam_pt_sprd    37498 non-null float64
# awayteam_opp_ppg    37498 non-null float64
# pyth_wp_home        37498 non-null float64
# pyth_wp_away        37498 non-null float64
# hometeam_ps_var     37498 non-null float64
# awayteam_ps_var     37498 non-null float64
# home_tovpct         37498 non-null float64
# away_tovpct         37498 non-null float64
# home_ft_factor      37498 non-null float64
# away_ft_factor      37498 non-null float64
# home_pace           37498 non-null float64
# away_pace           37498 non-null float64
# dtypes: float64(58)
# memory usage: 16.6 MB

# %%
df_features.hist(figsize=(20,20))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x1241e35c0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x124f52b70>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125a43550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125b52198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125f85f98>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125f85fd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125fc3c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125fe92e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x126007978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126030048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1260546d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126079d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1260ae438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1260d7ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126106198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12612e828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x126158eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126187588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1261afc18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1261e52e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12620c978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12623d048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1262646d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12628dd68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1262bf438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1262e8ac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12631a198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126341828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126369eb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12639c588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1263c3c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1263f72e8>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x126420978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12644f048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264786d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264a0d68>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264d1438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1264fcac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12652d198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126553828>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x12657ceb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1265ae588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1265d5c18>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266082e8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12662f978>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126664048>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12668a6d8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1266b1d68>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x1266e6438>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12670cac8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12673c198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126764828>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12678eeb8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1267bf588>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x125f45748>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126812e80>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x126843550>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12686bbe0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12689d2b0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1268c5940>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x1268effd0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x12691f6a0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126947d30>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x126979400>]],
#       dtype=object)

# %%
def home_minus_away(df,varlst):
    for var in varlst:
        df['diff{}'.format(var)] = df['home{}'.format(var)] - df['away{}'.format(var)]
